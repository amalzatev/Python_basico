# %% [markdown]
# <a href="https://colab.research.google.com/github/amalzatev/Python_basico/blob/main/CLASES_DE_DATOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tutorial python nativo

# %% [markdown]
# Comandos iniciales

# %%
print("hola UNAL")

# %%
C = "5"    # el igual asigna a la variable el valor
print(C)
Asignacion2 = 5
print(Asignacion2)

# %%
a = input('Cual es su nombre: ')  # input es el comando de entradas del usuario

print(f"me alegro conocerlo, {a}")

# %% [markdown]
# #CLASES DE DATOS

# %% [markdown]
# CADENAS O STRINGS: lista de caracteres de tipo texto.

# %%
d="danielfelipezdr1" 
len(d)

# %%
B= "Inteligencia Artificial"
print(type(B)) # muestra el tipo de clase, en este caso string
print (len(B)) # indica la cantidad de caracteres

# %% [markdown]
# # comandos para cadenas
# ![EJEMPLO CADENAS.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ENTEROS(INT) Y FLOTANTES(FLOAT):

# %%
C=5
print(type(C))
D=5
print(type(D))

# %% [markdown]
# ##### IMPORTANCIA DE CONOCER LOS TIPOS DE DATOS

# %%
# ejemplo de concatenacion
C=5
C=str(C)
print("El resultado es:" + C)

# %% [markdown]
# BOOLEANOS: SOLO TOMA DOS POSIBLES VALORES

# %%
# recordar 
< menor que 
> mayor que
== igual a
<= menor o igual que
>= mayor o igual que 
!= no es igual
is
not
or
and

# %%
print(3==3)  #compara y siempre tiene dos opciones: True o False
print(2==2)

# %%
#Operaciones logicas and = si ambos son verdaderos
a=True
b=False
opand = a and b 
print (opand) 
# asi es con or=si alguna es verdadera todo es verdadero y not=niega

# %%
a=True  # or = si alguno es verdadero, todo será V
b=False
opor = a or b
print (opor)
